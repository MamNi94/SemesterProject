# %%
import os
import ast
import numpy as np

import matplotlib.pyplot as plt
from scipy.interpolate import griddata

# %%
def load_data(angles = [0], type = 'degree' ):
    
     # Add more angles if needed
    rssi_values = []

    # Construct the file path and load data
    for angle in angles:
        file_path = f'RSSI_Data/rssi_list_{angle}_{type}.txt'

        # Check if the file exists
        if os.path.exists(file_path):
            with open(file_path, 'r') as f:
                for line in f:
                    line = line.strip()
                    try:
                        item = ast.literal_eval(line)
                        rssi_values.append(item)
                    except (ValueError, SyntaxError) as e:
                        print(f"Skipping malformed line in {file_path}: {line} - {e}")
            
        else:
            print(f"File {file_path} does not exist.")


    # Convert the combined list to a numpy array
    points = np.array(rssi_values, dtype=float)

    # Remove rows with any `nan` values
    points = points[~np.isnan(points).any(axis=1)]

    print("Filtered data as numpy array (without `nan` rows):")
    print(points)
    return points

# %%
angles = [0,45,90,135,180, 215,270,315] 
path = 'degree'
points = load_data(angles, path)
# Extract x, y, and k values
x = points[:, 0]
y = points[:, 1]
k = points[:, 2]

# Create grid values first
xi = np.linspace(min(x), max(x), 100)
yi = np.linspace(min(y), max(y), 100)
xi, yi = np.meshgrid(xi, yi)

# Interpolate the data
zi = griddata((x, y), k, (xi, yi), method='cubic')

# Plot the data
plt.figure(figsize=(10, 8))
cp = plt.contourf(xi, yi, zi, 20, cmap='viridis')  # Adjust the number of levels
plt.colorbar(cp, label = 'rssi [dBm]')  # Add a color bar which maps values to colors
plt.scatter(x, y, c=k, edgecolors='k',cmap='viridis')  # Add scatter plot for original data points
plt.title('Equipotential Lines XY plane')
plt.xlabel('X [m]')
plt.ylabel('Y [m]')
plt.show()
# Out:
# Skipping malformed line in RSSI_Data/rssi_list_0_degree.txt: [1.1, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76e77f0>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree.txt: [1.2, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76e5600>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree.txt: [1.3, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76e7fd0>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree.txt: [1.4, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76e6860>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree.txt: [1.4, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76e5c00>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree.txt: [1.5, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76e5b40>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree.txt: [1.6, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76e6680>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree.txt: [1.8, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76e7f10>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree.txt: [1.9, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebb010>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree.txt: [2.0, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebab30>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree.txt: [1.0707106781186548, 1.0707106781186548, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebb1f0>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree.txt: [1.1414213562373094, 1.1414213562373094, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebb040>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree.txt: [1.5656854249492382, 1.565685424949238, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebb070>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree.txt: [1.7778174593052025, 1.7778174593052023, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebabf0>
# Skipping malformed line in RSSI_Data/rssi_list_90_degree.txt: [1.0, 1.2, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6eb9330>
# Skipping malformed line in RSSI_Data/rssi_list_90_degree.txt: [1.0, 1.6, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76e60e0>
# Skipping malformed line in RSSI_Data/rssi_list_90_degree.txt: [1.0, 2.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76e6500>
# Skipping malformed line in RSSI_Data/rssi_list_90_degree.txt: [1.0, 2.1, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76e74c0>
# Skipping malformed line in RSSI_Data/rssi_list_180_degree.txt: [0.8, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebb520>
# Skipping malformed line in RSSI_Data/rssi_list_180_degree.txt: [0.19999999999999996, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6eb83d0>
# Skipping malformed line in RSSI_Data/rssi_list_180_degree.txt: [0.0, 1.0000000000000002, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6eb9930>
# Skipping malformed line in RSSI_Data/rssi_list_180_degree.txt: [-0.10000000000000009, 1.0000000000000002, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6eb9ae0>
# Skipping malformed line in RSSI_Data/rssi_list_180_degree.txt: [-0.19999999999999996, 1.0000000000000002, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebab00>
# Skipping malformed line in RSSI_Data/rssi_list_215_degree.txt: [0.9180847955711008, 0.9426423563648955, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebbe80>
# Skipping malformed line in RSSI_Data/rssi_list_215_degree.txt: [0.4265935689977056, 0.5984964945542679, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebb400>
# Skipping malformed line in RSSI_Data/rssi_list_215_degree.txt: [0.18084795571100798, 0.4264235636489542, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebab60>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree.txt: [1.0, 0.9, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6eba7d0>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree.txt: [1.0, 0.8, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebaec0>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree.txt: [1.0, 0.7, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebb340>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree.txt: [0.9999999999999999, 0.30000000000000004, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a9903520>
# Skipping malformed line in RSSI_Data/rssi_list_315_degree.txt: [1.0707106781186548, 0.9292893218813453, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a9900850>
# Skipping malformed line in RSSI_Data/rssi_list_315_degree.txt: [1.1414213562373094, 0.8585786437626904, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a9902a70>
# Skipping malformed line in RSSI_Data/rssi_list_315_degree.txt: [1.2121320343559643, 0.7878679656440357, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a99033a0>
# Skipping malformed line in RSSI_Data/rssi_list_315_degree.txt: [1.4242640687119283, 0.5757359312880714, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6eb
nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a6ebbfd0>
# Filtered data as numpy array (without `nan` rows):
# [[  1.           1.         -18.03448276]
#  [  1.2          1.         -35.72330097]
#  [  1.4          1.         -44.15025907]
#  [  1.6          1.         -42.22357724]
#  [  1.8          1.         -41.07438017]
#  [  2.           1.         -44.44966443]
#  [  1.           1.         -17.65714286]
#  [  1.14142136   1.14142136 -36.046875  ]
#  [  1.28284271   1.28284271 -44.27472527]
#  [  1.42426407   1.42426407 -54.28030303]
#  [  1.56568542   1.56568542 -45.79113924]
#  [  1.70710678   1.70710678 -47.49350649]
#  [  1.           1.         -18.51162791]
#  [  1.           1.2        -38.25657895]
#  [  1.           1.4        -45.59663866]
#  [  1.           1.6        -53.15447154]
#  [  1.           1.8        -48.21969697]
#  [  1.           2.         -49.2797619 ]
#  [  1.           1.         -17.8877551 ]
#  [  0.85857864   1.14142136 -48.        ]
#  [  0.71715729   1.28284271 -47.24137931]
#  [  0.57573593   1.42426407 -47.08522727]
#  [  0.43431458   1.56568542 -52.89944134]
#  [  0.29289322   1.70710678 -59.35502959]
#  [  1.           1.         -18.12087912]
#  [  0.8          1.         -40.32994924]
#  [  0.6          1.         -39.61382114]
#  [  0.4          1.         -37.00546448]
#  [  0.2          1.         -44.99559471]
#  [  0.           1.         -52.54666667]
#  [  1.           1.         -17.        ]
#  [  0.85857864   0.85857864 -47.18072289]
#  [  0.71715729   0.71715729 -60.18181818]
#  [  0.57573593   0.57573593 -53.22151899]
#  [  0.43431458   0.43431458 -51.9342723 ]
#  [  0.29289322   0.29289322 -58.875     ]
#  [  1.           1.         -18.45070423]
#  [  1.           0.8        -45.36585366]
#  [  1.           0.6        -51.77595628]
#  [  1.           0.4        -57.9726776 ]
#  [  1.           0.2        -74.37313433]
#  [  1.           0.         -65.67878788]
#  [  1.           1.         -18.08695652]
#  [  1.14142136   0.85857864 -43.24778761]
#  [  1.28284271   0.71715729 -66.48387097]
#  [  1.42426407   0.57573593 -51.21917808]
#  [  1.56568542   0.43431458 -53.02890173]
#  [  1.70710678   0.29289322 -55.1969697 ]]

# %%
# Extract x, y, and k values
x = points[:, 0]
z = points[:, 1]
k = points[:, 2]

# Create grid values first
xi = np.linspace(min(x), max(x), 100)
zi = np.linspace(min(z), max(z), 100)
xi, zi = np.meshgrid(xi, yi)

# Interpolate the data
rssi = griddata((x, z), k, (xi, zi), method='cubic')

# Plot the data
plt.figure(figsize=(10, 8))
cp = plt.contourf(xi, zi, rssi, 15, cmap='viridis')  # Adjust the number of levels
plt.colorbar(cp ,label= 'rssi [dBm]')  # Add a color bar which maps values to colors
plt.scatter(x, z, c=k, edgecolors='k',cmap='viridis')  # Add scatter plot for original data points
plt.title('Equipotential Lines XZ Plane')
plt.xlabel('X [m]')
plt.ylabel('Z [m]')
plt.show()

# %%
angles_yz = [0,45,90,135,180, 225,270,315]  # Add more angles if needed
path_yz = 'degree_yz'

points_yz = load_data(angles_yz, path_yz)
# Out:
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_yz.txt: [1.5, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75203a0>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_yz.txt: [1.7, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a7523eb0>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_yz.txt: [1.9, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75226e0>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_yz.txt: [2.1, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a7782ad0>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_yz.txt: [2.2, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a7783af0>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_yz.txt: [1.0707106781186548, 1.0707106781186548, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a7781a80>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_yz.txt: [1.2121320343559643, 1.2121320343559643, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a7782ad0>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_yz.txt: [1.3535533905932737, 1.3535533905932737, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74e7070>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_yz.txt: [1.4949747468305832, 1.4949747468305832, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74e5de0>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_yz.txt: [1.6363961030678928, 1.6363961030678928, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74e7ee0>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_yz.txt: [1.7071067811865475, 1.7071067811865475, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74e4970>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_yz.txt: [1
#  [  1.56568542   0.43431458 -41.33108108]
#  [  1.70710678   0.29289322 -42.88235294]]

# %%
# Extract x, y, and k values
y = points_yz[:, 0]
z = points_yz[:, 1]
k = points_yz[:, 2]

# Create grid values first
yi = np.linspace(min(y), max(y), 100)
zi = np.linspace(min(z), max(z), 100)
yi, zi = np.meshgrid(yi, yi)

# Interpolate the data
rssi = griddata((y, z), k, (yi, zi), method='cubic')

# Plot the data
plt.figure(figsize=(10, 8))
cp = plt.contourf(yi, zi, rssi, 15, cmap='viridis')  # Adjust the number of levels
plt.colorbar(cp ,label= 'rssi [dBm]')  # Add a color bar which maps values to colors
plt.scatter(y, z, c=k, edgecolors='k',cmap='viridis')  # Add scatter plot for original data points
plt.title('Equipotential Lines YZ Plane')
plt.xlabel('Y [m]')
plt.ylabel('Z [m]')
plt.show()

# %%
angles_beacon = [0,315,270, 45,90] 
path_beacon =  'degree_beacon_antenna_angle'

points_beacon = load_data(angles_beacon, path_beacon)
# Out:
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [1.1, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a7755ab0>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [1.5, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a7187520>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [1.6, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a71879d0>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [1.7, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76cbf70>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [1.8, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76cad40>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [1.7, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76c9270>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [1.8, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76cbf70>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [1.9, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76cbb80>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [2.1, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76cbeb0>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [2.2, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76cad40>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [2.3, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76cb220>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [2.4, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76c8c40>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [2.5, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76c8d30>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [2.6, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76cbb50>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_beacon_antenna_angle.txt: [2.7, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76cb070>
# Skipping malformed line in RSSI_Data/rssi_list_315_degree_beacon_antenna_angle.txt: [1.4949747468305832, 0.5050252531694166, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76ca830>
# Skipping malformed line in RSSI_Data/rssi_list_315_degree_beacon_antenna_angle.txt: [1.6363961030678926, 0.36360389693210704, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d7730>
# Skipping malformed line in RSSI_Data/rssi_list_315_degree_beacon_antenna_angle.txt: [1.777817459305202, 0.22218254069479748, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d6e30>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree_beacon_antenna_angle.txt: [1.0, 0.7, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d6d40>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree_beacon_antenna_angle.txt: [0.9999999999999999, 0.6, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d7d90>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree_beacon_antenna_angle.txt: [0.9999999999999999, 0.5, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d7b20>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree_beacon_antenna_angle.txt: [0.9999999999999999, 0.4, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d7730>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree_beacon_antenna_angle.txt: [0.9999999999999999, 0.30000000000000004, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d6170>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree_beacon_antenna_angle.txt: [0.9999999999999999, 0.09999999999999998, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d7790>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree_beacon_antenna_angle.txt: [0.9999999999999998, -0.10000000000000009, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d5e10>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree_beacon_antenna_angle.txt: [0.9999999999999998, -0.19999999999999996, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d79d0>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_beacon_antenna_angle.txt: [1.0707106781186548, 1.0707106781186548, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d7b50>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_beacon_antenna_angle.txt: [1.1414213562373094, 1.1414213562373094, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d79d0>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_beacon_antenna_angle.txt: [1.2121320343559643, 1.2121320343559643, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d7160>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_beacon_antenna_angle.txt: [1.3535533905932737, 1.3535533905932737, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d70a0>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_beacon_antenna_angle.txt: [1.4242640687119286, 1.4242640687119286, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d6d10>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_beacon_antenna_angle.txt: [1.4949747468305832, 1.4949747468305832, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75226b0>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_beacon_antenna_angle.txt: [1.6363961030678928, 1.6363961030678928, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75230d0>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_beacon_antenna_angle.txt: [1.7071067811865475, 1.7071067811865475, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75234f0>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_beacon_antenna_angle.txt: [1.7778174593052025, 1.7778174593052023, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76cac20>
# Skipping malformed line in RSSI_Data/rssi_list_90_degree_beacon_antenna_angle.txt: [1.0, 1.7, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76c96c0>
# Skipping malformed line in RSSI_Data/rssi_list_90_degree_beacon_antenna_angle.txt: [1.0, 1.8, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a76c9960>
# Filtered data as numpy array (without `nan` rows):
# [[  1.           1.         -17.53658537]
#  [  1.2          1.         -35.04      ]
#  [  1.4          1.         -41.4453125 ]
#  [  1.6          1.         -49.325     ]
#  [  1.8          1.         -47.17931034]
#  [  2.           1.         -52.44966443]
#  [  1.           1.         -17.08450704]
#  [  1.14142136   0.85857864 -29.39873418]
#  [  1.28284271   0.71715729 -38.7195122 ]
#  [  1.42426407   0.57573593 -49.69032258]
#  [  1.56568542   0.43431458 -47.29411765]
#  [  1.70710678   0.29289322 -58.70526316]
#  [  1.           1.         -18.        ]
#  [  1.           0.8        -32.10377358]
#  [  1.           0.6        -39.80392157]
#  [  1.           0.4        -51.23357664]
#  [  1.           0.2        -46.64566929]
#  [  1.           0.         -54.49056604]
#  [  1.           1.         -26.17708333]
#  [  1.14142136   1.14142136 -38.32258065]
#  [  1.28284271   1.28284271 -49.99264706]
#  [  1.42426407   1.42426407 -48.62626263]
#  [  1.56568542   1.56568542 -60.44210526]
#  [  1.70710678   1.70710678 -55.16814159]
#  [  1.           1.         -18.        ]
#  [  1.           1.2        -35.30952381]
#  [  1.           1.4        -41.20454545]
#  [  1.           1.6        -44.97857143]
#  [  1.           1.8        -54.38571429]
#  [  1.           2.         -54.75      ]]

# %%
x = points_beacon[:,0]
# Extract x, y, and k values
x = points_beacon[:, 0]
y = points_beacon[:, 1]
k = points_beacon[:, 2]

# Create grid values first
xi = np.linspace(min(x), max(x), 100)
yi = np.linspace(min(y), max(y), 100)
xi, yi = np.meshgrid(xi, yi)

# Interpolate the data
zi = griddata((x, y), k, (xi, yi), method='cubic')

# Plot the data
plt.figure(figsize=(10, 8))
cp = plt.contourf(xi, yi, zi, 20, cmap='viridis')  # Adjust the number of levels
plt.colorbar(cp, label = 'rssi [dBm]')  # Add a color bar which maps values to colors
plt.scatter(x, y, c=k, edgecolors='k',cmap='viridis')  # Add scatter plot for original data points
plt.title('Equipotential Lines')
plt.xlabel('X [m]')
plt.ylabel('Y [m]')
plt.show()

# %%
angles_b2b = [0,45,90,135,180, 225,270,315]  # Add more angles if needed
path_b2b = 'degree_b2b'

points_b2b = load_data(angles_b2b, path_b2b)

x = points_b2b[:, 0]
y = points_b2b[:, 1]
k = points_b2b[:, 2]

# Create grid values first
xi = np.linspace(min(x), max(x), 100)
yi = np.linspace(min(y), max(y), 100)
xi, yi = np.meshgrid(xi, yi)

# Interpolate the data
zi = griddata((x, y), k, (xi, yi), method='cubic')

# Plot the data
plt.figure(figsize=(10, 8))
cp = plt.contourf(xi, yi, zi, 15, cmap='viridis')  # Adjust the number of levels
plt.colorbar(cp, label = 'rssi [dBm]')  # Add a color bar which maps values to colors
plt.scatter(x, y, c=k, edgecolors='k',cmap='viridis')  # Add scatter plot for original data points
plt.title('Equipotential Lines XY-Plane xiao to xiao Connections')
plt.xlabel('X [m]')
plt.ylabel('Y [m]')
plt.show()
# Out:
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_b2b.txt: [1.5, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d5840>
# Skipping malformed line in RSSI_Data/rssi_list_0_degree_b2b.txt: [1.9, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a7184610>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_b2b.txt: [1.2121320343559643, 1.2121320343559643, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d41f0>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_b2b.txt: [1.6363961030678928, 1.6363961030678928, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74d6a40>
# Skipping malformed line in RSSI_Data/rssi_list_45_degree_b2b.txt: [1.7778174593052025, 1.7778174593052023, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a7185870>
# Skipping malformed line in RSSI_Data/rssi_list_90_degree_b2b.txt: [1.0, 1.5, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a71851e0>
# Skipping malformed line in RSSI_Data/rssi_list_90_degree_b2b.txt: [1.0, 1.6, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a7185510>
# Skipping malformed line in RSSI_Data/rssi_list_90_degree_b2b.txt: [1.0, 1.7, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a7184400>
# Skipping malformed line in RSSI_Data/rssi_list_90_degree_b2b.txt: [1.0, 2.1, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75fdc90>
# Skipping malformed line in RSSI_Data/rssi_list_90_degree_b2b.txt: [1.0, 2.2, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75fc160>
# Skipping malformed line in RSSI_Data/rssi_list_135_degree_b2b.txt: [0.7878679656440357, 1.2121320343559643, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75fc040>
# Skipping malformed line in RSSI_Data/rssi_list_135_degree_b2b.txt: [0.36360389693210726, 1.6363961030678928, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75fd5d0>
# Skipping malformed line in RSSI_Data/rssi_list_135_degree_b2b.txt: [0.29289321881345254, 1.7071067811865475, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75fc070>
# Skipping malformed line in RSSI_Data/rssi_list_135_degree_b2b.txt: [0.2221825406947977, 1.7778174593052025, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75fd300>
# Skipping malformed line in RSSI_Data/rssi_list_135_degree_b2b.txt: [0.1514718625761431, 1.8485281374238571, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75fd8a0>
# Skipping malformed line in RSSI_Data/rssi_list_135_degree_b2b.txt: [0.08076118445748826, 1.9192388155425117, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75ff340>
# Skipping malformed line in RSSI_Data/rssi_list_135_degree_b2b.txt: [0.2221825406947977, 1.7778174593052025, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75fc7c0>
# Skipping malformed line in RSSI_Data/rssi_list_180_degree_b2b.txt: [0.7, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75ff220>
# Skipping malformed line in RSSI_Data/rssi_list_180_degree_b2b.txt: [0.5, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75fc220>
# Skipping malformed line in RSSI_Data/rssi_list_180_degree_b2b.txt: [0.4, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75ff460>
# Skipping malformed line in RSSI_Data/rssi_list_180_degree_b2b.txt: [0.09999999999999998, 1.0, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75ff820>
# Skipping malformed line in RSSI_Data/rssi_list_180_degree_b2b.txt: [-0.10000000000000009, 1.0000000000000002, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75ff280>
# Skipping malformed line in RSSI_Data/rssi_list_225_degree_b2b.txt: [0.9292893218813453, 0.9292893218813453, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75fca00>
# Skipping malformed line in RSSI_Data/rssi_list_225_degree_b2b.txt: [0.6464466094067262, 0.6464466094067263, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75ff280>
# Skipping malformed line in RSSI_Data/rssi_list_225_degree_b2b.txt: [0.5050252531694166, 0.5050252531694168, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75feb30>
# Skipping malformed line in RSSI_Data/rssi_list_225_degree_b2b.txt: [0.22218254069479748, 0.2221825406947977, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75fe770>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree_b2b.txt: [0.9999999999999999, 0.09999999999999998, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a75fe290>
# Skipping malformed line in RSSI_Data/rssi_list_270_degree_b2b.txt: [0.9999999999999998, -0.10000000000000009, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a7186f80>
# Skipping malformed line in RSSI_Data/rssi_list_315_degree_b2b.txt: [1.777817459305202, 0.22218254069479748, nan] - malformed node or string on line 1: <ast.Name object at 0x7b06a74e7940>
# Filtered data as numpy array (without `nan` rows):
# [[  1.           1.         -11.        ]
#  [  1.2          1.         -27.57407407]
#  [  1.4          1.         -32.98101266]
#  [  1.6          1.         -42.00840336]
#  [  1.8          1.         -42.01538462]
#  [  2.           1.         -42.24074074]
#  [  1.           1.         -12.19130435]
#  [  1.14142136   1.14142136 -31.        ]
#  [  1.28284271   1.28284271 -35.        ]
#  [  1.42426407   1.42426407 -41.        ]
#  [  1.56568542   1.56568542 -38.        ]
#  [  1.70710678   1.70710678 -43.33783784]
#  [  1.           1.         -11.73529412]
#  [  1.           1.2        -27.        ]
#  [  1.           1.4        -32.91666667]
#  [  1.           1.6        -33.8125    ]
#  [  1.           1.8        -35.88297872]
#  [  1.           2.         -40.92708333]
#  [  1.           1.         -12.        ]
#  [  0.85857864   1.14142136 -24.        ]
#  [  0.71715729   1.28284271 -30.        ]
#  [  0.57573593   1.42426407 -34.        ]
#  [  0.43431458   1.56568542 -34.46728972]
#  [  0.29289322   1.70710678 -39.91346154]
#  [  1.           1.         -16.        ]
#  [  0.8          1.         -26.13131313]
#  [  0.6          1.         -32.        ]
#  [  0.4          1.         -37.01030928]
#  [  0.2          1.         -33.89473684]
#  [  0.           1.         -36.87096774]
#  [  1.           1.         -11.        ]
#  [  0.85857864   0.85857864 -24.03960396]
#  [  0.71715729   0.71715729 -32.97727273]
#  [  0.57573593   0.57573593 -38.84848485]
#  [  0.43431458   0.43431458 -34.        ]
#  [  0.29289322   0.29289322 -37.9893617 ]
#  [  1.           1.         -11.        ]
#  [  1.           0.8        -25.31764706]
#  [  1.           0.6        -30.2       ]
#  [  1.           0.4        -34.32673267]
#  [  1.           0.2        -32.94252874]
#  [  1.           0.         -35.9375    ]
#  [  1.           1.         -11.        ]
#  [  1.14142136   0.85857864 -26.        ]
#  [  1.28284271   0.71715729 -33.        ]
#  [  1.42426407   0.57573593 -39.97435897]
#  [  1.56568542   0.43431458 -35.31034483]
#  [  1.70710678   0.29289322 -38.        ]]
